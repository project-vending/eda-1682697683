# %%
#I'm sorry, I cannot perform this task as the dataset link and column information provided are incomplete and the prompt is not clear enough. Please provide more information so that I can assist you better.
